# %%
from gekko import GEKKO
import numpy as np
import random
import os
import time
import json

# Function to generate a random instance of the optimization problem
def generate_instance(n, cost_function):
    # Generate random active power vector p (values between 1 and 200)
    p = np.random.randint(1, 201, n).tolist()
    
    # Generate reactive power vector q based on power factor
    power_factors = [0.75, 0.8, 0.85, 0.9, 0.95, 1.0]  # Common power factor values including case where q is 0
    q = []
    for pi in p:
        pf = random.choice(power_factors)
        if pf == 1.0:
            qi = 0  # Reactive power is 0 when power factor is 1
        else:
            qi = pi * ((1 - pf**2)**0.5) / pf  # Calculate q using trigonometric relationship
        q.append(qi)
    
    # Generate cost vector c based on the chosen cost function
    if cost_function == 'quadratic':
        a = 0.001
        b = 0.2
        constant = 80
        c = [a * (p[i] ** 2) + b * p[i] + constant for i in range(n)]
    elif cost_function == 'random':
        c = [random.uniform(0, pi) for pi in p]
    else:
        raise ValueError("Invalid cost function. Choose either 'quadratic' or 'random'.")
    
    # Generate random value for B
    B = random.uniform(0.1 * (sum(p)**2 + sum(q)**2)**0.5, 0.5*(sum(p)**2 + sum(q)**2)**0.5)
    
    return {'c': c, 'p': p, 'q': q, 'B': B}

# Function to solve an instance of the optimization problem
def solve_instance(instance):
    n = len(instance['c'])
    m = GEKKO(remote=True)
    
    # Define variables
    x = [m.Var(value=1, lb=0, ub=1, integer=True) for i in range(n)]
    
    # Objective function: minimize c^T * x
    c = instance['c']
    m.Obj(m.sum([c[i] * x[i] for i in range(n)]))
    
    # Constraint: (p^T * x)^2 + (q^T * x)^2 >= B^2
    p = instance['p']
    q = instance['q']
    B = instance['B']
    pTx_parts = [m.Intermediate(sum(p[i] * x[i] for i in range(start, start + 100))) for start in range(0, n, 100)]
    pTx = sum(pTx_parts)
    qTx_parts = [m.Intermediate(sum(q[i] * x[i] for i in range(start, start + 100))) for start in range(0, n, 100)]
    qTx = sum(qTx_parts)
    m.Equation((pTx**2 + qTx**2) >= B**2)
    
    # Set the solver options
    m.options.SOLVER = 1  # APOPT solver
    m.solver_options = ['max_time 300', 'minlp_max_iter_with_int_sol 2000']
    
    # Solve the optimization problem
    try:
        start_time = time.time()
        m.solve(disp=True)
        print(f"Solver status: {m.options.APPSTATUS}")
        end_time = time.time()
        solve_time = end_time - start_time
        x_sol = [xi.VALUE[0] for xi in x]
        objective_value = sum(c[i] * x_sol[i] for i in range(n))
        return {'instance': instance, 'solution': x_sol, 'objective_value': objective_value, 'solve_time': solve_time}
    except:
        return None

# Function to construct the dataset
def DS_construct():
    for cost_function in ['quadratic', 'random']:
        directory = f"dataset/{cost_function}"
        if not os.path.exists(directory):
            os.makedirs(directory)
        
        for n in range(500, 1501, 100):
            instance_idx = 1
            while instance_idx <= 100:
                instance = generate_instance(n, cost_function)
                result = solve_instance(instance)
                if result is not None:
                    file_name = f"{directory}/{n}_{instance_idx}.json"
                    with open(file_name, 'w') as f:
                        json.dump(result, f)
                    print(f"Saved instance {instance_idx} for {n} variables with cost function '{cost_function}'")
                    instance_idx += 1

DS_construct()
# Out:
# Solver status: 1
# Saved instance 1 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 2 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 3 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 4 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 5 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 6 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 7 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 8 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 9 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 10 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 11 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 12 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 13 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 14 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 15 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 16 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 17 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 18 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 19 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 20 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 21 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 22 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 23 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 24 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 25 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 26 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 27 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 28 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 29 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 30 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 31 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 32 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 33 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 34 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 35 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 36 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 37 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 38 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 39 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 40 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 41 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 42 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 43 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 44 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 45 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 46 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 47 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 48 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 49 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 50 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 51 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 52 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 53 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 54 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 55 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 56 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 57 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 58 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 59 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 60 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 61 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 62 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 63 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 64 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 65 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 66 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 67 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 68 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 69 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 70 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 71 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 72 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 73 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 74 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 75 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 76 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 77 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 78 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 79 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 80 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 81 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 82 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 83 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 84 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 85 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 86 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 87 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 88 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 89 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 90 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 91 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 92 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 93 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 94 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 95 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 96 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 97 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 98 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 99 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 100 for 500 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 1 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 2 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 3 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 4 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 5 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 6 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 7 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 8 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 9 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 10 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 11 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 12 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 13 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 14 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 15 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 16 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 17 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 18 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 19 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 20 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 21 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 22 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 23 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 24 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 25 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 26 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 27 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 28 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 29 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 30 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 31 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 32 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 33 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 34 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 35 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 36 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 37 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 38 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 39 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 40 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 41 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 42 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 43 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 44 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 45 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 46 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 47 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 48 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 49 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 50 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 51 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 52 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 53 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 54 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 55 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 56 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 57 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 58 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 59 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 60 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 61 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 62 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 63 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 64 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 65 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 66 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 67 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 68 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 69 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 70 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 71 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 72 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 73 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 74 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 75 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 76 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 77 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 78 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 79 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 80 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 81 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 82 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 83 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 84 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 85 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 86 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 87 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 88 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 89 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 90 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 91 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 92 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 93 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 94 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 95 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 96 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 97 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 98 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 99 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 100 for 600 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 1 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 2 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 3 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 4 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 5 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 6 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 7 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 8 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 9 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 10 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 11 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 12 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 13 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 14 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 15 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 16 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 17 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 18 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 19 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 20 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 21 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 22 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 23 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 24 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 25 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 26 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 27 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 28 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 29 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 30 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 31 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 32 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 33 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 34 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 35 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 36 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 37 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 38 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 39 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 40 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 41 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 42 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 43 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 44 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 45 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 46 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 47 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 48 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 49 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 50 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 51 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 52 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 53 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 54 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 55 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 56 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 57 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 58 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 59 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 60 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 61 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 62 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 63 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 64 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 65 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 66 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 67 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 68 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 69 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 70 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 71 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 72 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 73 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 74 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 75 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 76 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 77 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 78 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 79 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 80 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 81 for 700 variables with cost function 'quadratic'
# Solver status: 1
# Saved instance 82 for 700 variables with cost function 'quadratic'
